# %% [markdown]
# # DATA SCIENCE INTERNSHIP @BHARAT INTERN

# %% [markdown]
# ## SEPTEMBER-OCTOBER BATCH

# %% [markdown]
# ### NAME : PRATEEK TYAGI

# %% [markdown]
# # Task 1- Stock Prediction

# %% [markdown]
# ## Objective : Take stock price of any company you want and predicts its price by using LSTM.

# %% [markdown]
# ## ABOUT DATASET
# ### Apple Stock Prediction
#
# This dataset contains historical data of **Apple's stock prices** and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
#
# The columns in the dataset are as follows:
#
# 1. **Symbol**: The name of the company, which is **AAPL** in this case.
# 2. **Date**: The year and date of the stock data.
# 3. **Close**: The closing price of Apple's stock on a particular day.
# 4. **High**: The highest value reached by Apple's stock on the given day.
# 5. **Low**: The lowest value reached by Apple's stock on the given day.
# 6. **Open**: The opening value of Apple's stock on the given day.
# 7. **Volume**: The trading volume of Apple's stock on the given day, i.e., the number of shares traded.
# 8. **adjClose**: The adjusted closing price of Apple's stock, considering factors such as dividends and stock splits.
# 9. **adjHigh**: The adjusted highest value reached by Apple's stock on the given day.
# 10. **adjLow**: The adjusted lowest value reached by Apple's stock on the given day.
# 11. **adjOpen**: The adjusted opening value of Apple's stock on the given day.
# 12. **adjVolume**: The adjusted trading volume of Apple's stock on the given day, accounting for factors such as stock splits.
# 13. **divCash**: The amount of cash dividend paid out to shareholders on the given day.
# 14. **splitFactor**: The split factor, if any, applied to Apple's stock on the given day. A split factor of 1 indicates no split.

# %% [markdown]
# ## STEPS :
# ### 1 . IMPORTING LIBRARIES AND DATA TO BE USED
# ### 2. GATHERING INSIGHTS
# ### 3. DATA PRE-PROCESSING
# ### 4. CREATING LSTM MODEL
# ### 5. VISUALIZING ACTUAL VS PREDICTED DATA
# ### 6. PREDICTING UPCOMING 15 DAYS

# %% [markdown]
# ## STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from datetime import datetime, timedelta

# %%
df = pd.read_csv('AAPL.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
# 5           5   AAPL  2015-06-03 00:00:00+00:00  130.120  130.940  129.90
# 6           6   AAPL  2015-06-04 00:00:00+00:00  129.360  130.580  128.91
# 7           7   AAPL  2015-06-05 00:00:00+00:00  128.650  129.690  128.36
# 8           8   AAPL  2015-06-08 00:00:00+00:00  127.800  129.210  126.83
# 9           9   AAPL  2015-06-09 00:00:00+00:00  127.420  128.080  125.62
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
# 5  130.66  30983542  119.908625  120.664274  119.705890  120.406248
# 6  129.58  38450118  119.208267  120.332526  118.793582  119.411002
# 7  129.50  35626800  118.553986  119.512370  118.286744  119.337280
# 8  128.90  52674786  117.770691  119.070039  116.876813  118.784366
# 9  126.70  56075420  117.420512  118.028717  115.761770  116.757015
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# 2   50884452      0.0          1.0
# 3   32112797      0.0          1.0
# 4   33667627      0.0          1.0
# 5   30983542      0.0          1.0
# 6   38450118      0.0          1.0
# 7   35626800      0.0          1.0
# 8   52674786      0.0          1.0
# 9   56075420      0.0          1.0

# %% [markdown]
# ## STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 15)

# %%
# statistical description of data
df.describe()
# Out:
#         Unnamed: 0        close         high          low         open  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    628.500000   167.723998   169.230475   166.039780   167.548266
# std     363.297628    56.850796    57.500128    56.006773    56.612707
# min       0.000000    90.340000    91.670000    89.470000    90.000000
# 25%     314.250000   116.327500   117.405000   115.602500   116.482500
# 50%     628.500000   160.485000   162.080000   158.974250   160.345000
# 75%     942.750000   199.785000   201.277500   198.170000   199.520000
# max    1257.000000   327.200000   327.850000   323.350000   324.730000
#
#              volume     adjClose      adjHigh       adjLow      adjOpen  \
# count  1.258000e+03  1258.000000  1258.000000  1258.000000  1258.000000
# mean   3.500397e+07   162.666715   164.131054   161.028013   162.493082
# std    1.729100e+07    58.733820    59.402842    57.869246    58.494560
# min    1.136204e+07    84.954351    86.205062    84.136216    84.634620
# 25%    2.359205e+07   109.484490   110.393556   107.962457   109.135002
# 50%    3.064771e+07   154.710645   156.091874   153.054341   154.410017
# 75%    4.100487e+07   196.960053   198.428438   195.281553   196.452903
# max    1.622063e+08   326.337147   326.357095   322.497300   323.873661
#
#           adjVolume      divCash  splitFactor
# count  1.258000e+03  1258.000000       1258.0
# mean   3.500397e+07     0.010477          1.0
# std    1.729100e+07     0.083366          0.0
# min    1.136204e+07     0.000000          1.0
# 25%    2.359205e+07     0.000000          1.0
# 50%    3.064771e+07     0.000000          1.0
# 75%    4.100487e+07     0.000000          1.0
# max    1.622063e+08     0.820000          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1258 non-null   int64
#  1   symbol       1258 non-null   object
#  2   date         1258 non-null   object
#  3   close        1258 non-null   float64
#  4   high         1258 non-null   float64
#  5   low          1258 non-null   float64
#  6   open         1258 non-null   float64
#  7   volume       1258 non-null   int64
#  8   adjClose     1258 non-null   float64
#  9   adjHigh      1258 non-null   float64
#  10  adjLow       1258 non-null   float64
#  11  adjOpen      1258 non-null   float64
#  12  adjVolume    1258 non-null   int64
#  13  divCash      1258 non-null   float64
#  14  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(3), object(2)
# memory usage: 147.6+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# Unnamed: 0     0
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# ### There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open    close
# date
# 2015-05-27  130.34  132.045
# 2015-05-28  131.86  131.780
# 2015-05-29  131.23  130.280
# 2015-06-01  131.20  130.535
# 2015-06-02  129.86  129.960
# 2015-06-03  130.66  130.120
# 2015-06-04  129.58  129.360
# 2015-06-05  129.50  128.650
# 2015-06-08  128.90  127.800
# 2015-06-09  126.70  127.420

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='green')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ## STEP 3 : DATA PRE-PROCESSING

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2015-05-27  0.171857  0.176074
# 2015-05-28  0.178333  0.174956
# 2015-05-29  0.175649  0.168623
# 2015-06-01  0.175521  0.169699
# 2015-06-02  0.169812  0.167272
# 2015-06-03  0.173220  0.167947
# 2015-06-04  0.168619  0.164739
# 2015-06-05  0.168278  0.161741
# 2015-06-08  0.165722  0.158152
# 2015-06-09  0.156350  0.156548

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ## STEP 4 :  CREATING LSTM MODEL

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 5s 64ms/step - loss: 0.0135 - mean_absolute_error: 0.0800 - val_loss: 0.0145 - val_mean_absolute_error: 0.1007
# Epoch 2/100
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 0.0034 - val_mean_absolute_error: 0.0431
# Epoch 3/100
# 28/28 [==============================] - 1s 34ms/step - loss: 7.9861e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0048 - val_mean_absolute_error: 0.0570
# Epoch 4/100
# 28/28 [==============================] - 1s 33ms/step - loss: 7.1503e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0048 - val_mean_absolute_error: 0.0573
# Epoch 5/100
# 28/28 [==============================] - 1s 35ms/step - loss: 6.5946e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0040 - val_mean_absolute_error: 0.0516
# Epoch 6/100
# 28/28 [==============================] - 1s 35ms/step - loss: 6.2993e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0039 - val_mean_absolute_error: 0.0510
# Epoch 7/100
# 28/28 [==============================] - 1s 33ms/step - loss: 5.5429e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0031 - val_mean_absolute_error: 0.0448
# Epoch 8/100
# 28/28 [==============================] - 1s 33ms/step - loss: 5.6016e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0032 - val_mean_absolute_error: 0.0458
# Epoch 9/100
# 28/28 [==============================] - 1s 35ms/step - loss: 5.0983e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0033 - val_mean_absolute_error: 0.0468
# Epoch 10/100
# 28/28 [==============================] - 1s 36ms/step - loss: 5.7366e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0057 - val_mean_absolute_error: 0.0640
# Epoch 11/100
# 28/28 [==============================] - 1s 34ms/step - loss: 5.2828e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0028 - val_mean_absolute_error: 0.0426
# Epoch 12/100
# 28/28 [==============================] - 1s 39ms/step - loss: 4.9103e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0043 - val_mean_absolute_error: 0.0541
# Epoch 13/100
# 28/28 [==============================] - 1s 39ms/step - loss: 4.8589e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0039 - val_mean_absolute_error: 0.0515
# Epoch 14/100
# 28/28 [==============================] - 1s 39ms/step - loss: 4.3225e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0046 - val_mean_absolute_error: 0.0568
# Epoch 15/100
# 28/28 [==============================] - 1s 35ms/step - loss: 4.8026e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0016 - val_mean_absolute_error: 0.0300
# Epoch 16/100
# 28/28 [==============================] - 1s 35ms/step - loss: 4.8212e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0035 - val_mean_absolute_error: 0.0490
# Epoch 17/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.1810e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0021 - val_mean_absolute_error: 0.0363
# Epoch 18/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.0565e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0022 - val_mean_absolute_error: 0.0371
# Epoch 19/100
# 28/28 [==============================] - 1s 35ms/step - loss: 4.0479e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0016 - val_mean_absolute_error: 0.0309
# Epoch 20/100
# 28/28 [==============================] - 1s 37ms/step - loss: 4.0365e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0022 - val_mean_absolute_error: 0.0374
# Epoch 21/100
# 28/28 [==============================] - 1s 37ms/step - loss: 3.8890e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0033 - val_mean_absolute_error: 0.0462
# Epoch 22/100
# 28/28 [==============================] - 1s 37ms/step - loss: 3.8049e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0020 - val_mean_absolute_error: 0.0348
# Epoch 23/100
# 28/28 [==============================] - 1s 37ms/step - loss: 3.7549e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 24/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.8923e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0016 - val_mean_absolute_error: 0.0309
# Epoch 25/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.2319e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 26/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.8990e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 27/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.5561e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 28/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.7242e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0036 - val_mean_absolute_error: 0.0494
# Epoch 29/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.4382e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0016 - val_mean_absolute_error: 0.0307
# Epoch 30/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.6990e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0036 - val_mean_absolute_error: 0.0497
# Epoch 31/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.2213e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 32/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.5111e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0018 - val_mean_absolute_error: 0.0334
# Epoch 33/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.3079e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 34/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.4382e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 35/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.1870e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0029 - val_mean_absolute_error: 0.0441
# Epoch 36/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.1949e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 37/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.0616e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
# Epoch 38/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.0471e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0024 - val_mean_absolute_error: 0.0399
# Epoch 39/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.8935e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0029 - val_mean_absolute_error: 0.0443
# Epoch 40/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.1155e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 41/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.2420e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 42/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.8673e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 43/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.5214e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 44/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.0151e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292
# Epoch 45/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.9811e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 46/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.0501e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 47/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.8343e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 48/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.0642e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0026 - val_mean_absolute_error: 0.0427
# Epoch 49/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.9228e-04 - mean_absolute_error: 0.0125 - val_loss: 9.3792e-04 - val_mean_absolute_error: 0.0217
# Epoch 50/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.6374e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0021 - val_mean_absolute_error: 0.0370
# Epoch 51/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.9621e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0023 - val_mean_absolute_error: 0.0393
# Epoch 52/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.8109e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0018 - val_mean_absolute_error: 0.0339
# Epoch 53/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.8539e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 54/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.8050e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 55/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.4868e-04 - mean_absolute_error: 0.0114 - val_loss: 9.1968e-04 - val_mean_absolute_error: 0.0219
# Epoch 56/100
# 28/28 [==============================] - 1s 39ms/step - loss: 2.4866e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 57/100
# 28/28 [==============================] - 1s 39ms/step - loss: 2.4753e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0010 - val_mean_absolute_error: 0.0238
# Epoch 58/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.6285e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 59/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.6097e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 60/100
# 28/28 [==============================] - 1s 38ms/step - loss: 2.3991e-04 - mean_absolute_error: 0.0111 - val_loss: 9.3878e-04 - val_mean_absolute_error: 0.0223
# Epoch 61/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.7381e-04 - mean_absolute_error: 0.0119 - val_loss: 8.4787e-04 - val_mean_absolute_error: 0.0205
# Epoch 62/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.3594e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0016 - val_mean_absolute_error: 0.0318
# Epoch 63/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.3878e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 64/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.2459e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 65/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.2669e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 66/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.3143e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 67/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.1856e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 68/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.3211e-04 - mean_absolute_error: 0.0111 - val_loss: 9.7828e-04 - val_mean_absolute_error: 0.0228
# Epoch 69/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.4006e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 70/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.1001e-04 - mean_absolute_error: 0.0104 - val_loss: 8.9735e-04 - val_mean_absolute_error: 0.0218
# Epoch 71/100
# 28/28 [==============================] - 1s 37ms/step - loss: 2.0604e-04 - mean_absolute_error: 0.0105 - val_loss: 8.5488e-04 - val_mean_absolute_error: 0.0210
# Epoch 72/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.0313e-04 - mean_absolute_error: 0.0102 - val_loss: 7.6847e-04 - val_mean_absolute_error: 0.0187
# Epoch 73/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.3253e-04 - mean_absolute_error: 0.0109 - val_loss: 7.9030e-04 - val_mean_absolute_error: 0.0196
# Epoch 74/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.2390e-04 - mean_absolute_error: 0.0108 - val_loss: 8.5123e-04 - val_mean_absolute_error: 0.0205
# Epoch 75/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.4635e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 76/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.9737e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0021 - val_mean_absolute_error: 0.0371
# Epoch 77/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.0367e-04 - mean_absolute_error: 0.0102 - val_loss: 9.9997e-04 - val_mean_absolute_error: 0.0233
# Epoch 78/100
# 28/28 [==============================] - 1s 32ms/step - loss: 2.0246e-04 - mean_absolute_error: 0.0103 - val_loss: 8.0979e-04 - val_mean_absolute_error: 0.0204
# Epoch 79/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.9796e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 80/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.3327e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0021 - val_mean_absolute_error: 0.0375
# Epoch 81/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.1101e-04 - mean_absolute_error: 0.0103 - val_loss: 8.4822e-04 - val_mean_absolute_error: 0.0212
# Epoch 82/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.8942e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 83/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.0386e-04 - mean_absolute_error: 0.0101 - val_loss: 7.4769e-04 - val_mean_absolute_error: 0.0191
# Epoch 84/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.9436e-04 - mean_absolute_error: 0.0104 - val_loss: 7.9252e-04 - val_mean_absolute_error: 0.0201
# Epoch 85/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.8227e-04 - mean_absolute_error: 0.0097 - val_loss: 7.5719e-04 - val_mean_absolute_error: 0.0196
# Epoch 86/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.9301e-04 - mean_absolute_error: 0.0100 - val_loss: 7.3417e-04 - val_mean_absolute_error: 0.0188
# Epoch 87/100
# 28/28 [==============================] - 1s 36ms/step - loss: 2.0649e-04 - mean_absolute_error: 0.0105 - val_loss: 8.1950e-04 - val_mean_absolute_error: 0.0207
# Epoch 88/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.7167e-04 - mean_absolute_error: 0.0093 - val_loss: 9.8811e-04 - val_mean_absolute_error: 0.0240
# Epoch 89/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.7847e-04 - mean_absolute_error: 0.0094 - val_loss: 6.8131e-04 - val_mean_absolute_error: 0.0176
# Epoch 90/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.7343e-04 - mean_absolute_error: 0.0093 - val_loss: 7.7175e-04 - val_mean_absolute_error: 0.0202
# Epoch 91/100
# 28/28 [==============================] - 1s 37ms/step - loss: 1.7679e-04 - mean_absolute_error: 0.0098 - val_loss: 7.1790e-04 - val_mean_absolute_error: 0.0182
# Epoch 92/100
# 28/28 [==============================] - 1s 38ms/step - loss: 1.9328e-04 - mean_absolute_error: 0.0100 - val_loss: 8.7483e-04 - val_mean_absolute_error: 0.0219
# Epoch 93/100
# 28/28 [==============================] - 1s 33ms/step - loss: 1.6866e-04 - mean_absolute_error: 0.0093 - val_loss: 7.6211e-04 - val_mean_absolute_error: 0.0193
# Epoch 94/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.7029e-04 - mean_absolute_error: 0.0092 - val_loss: 7.1714e-04 - val_mean_absolute_error: 0.0183
# Epoch 95/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.6145e-04 - mean_absolute_error: 0.0091 - val_loss: 6.9705e-04 - val_mean_absolute_error: 0.0181
# Epoch 96/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.8230e-04 - mean_absolute_error: 0.0098 - val_loss: 9.0971e-04 - val_mean_absolute_error: 0.0216
# Epoch 97/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.6921e-04 - mean_absolute_error: 0.0093 - val_loss: 7.6781e-04 - val_mean_absolute_error: 0.0194
# Epoch 98/100
# 28/28 [==============================] - 1s 30ms/step - loss: 1.7387e-04 - mean_absolute_error: 0.0093 - val_loss: 7.1698e-04 - val_mean_absolute_error: 0.0185
# Epoch 99/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.7924e-04 - mean_absolute_error: 0.0094 - val_loss: 6.6205e-04 - val_mean_absolute_error: 0.0175
# Epoch 100/100
# 28/28 [==============================] - 1s 31ms/step - loss: 1.5931e-04 - mean_absolute_error: 0.0090 - val_loss: 6.9249e-04 - val_mean_absolute_error: 0.0181

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 11ms/step
# array([[0.51024157, 0.49965623],
#        [0.49879792, 0.48799863],
#        [0.48872653, 0.47826138],
#        [0.47701028, 0.46680328],
#        [0.44923002, 0.43806455]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[209.76901, 208.68858],
#        [207.08284, 205.92735],
#        [204.71878, 203.621  ],
#        [201.96863, 200.90703],
#        [195.44777, 194.09998]], dtype=float32)

# %% [markdown]
# ## STEP 5 :  VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open   close  open_predicted  close_predicted
# date
# 2019-05-08  201.900  202.90      209.769012       208.688583
# 2019-05-09  200.400  200.72      207.082840       205.927353
# 2019-05-10  197.419  197.18      204.718781       203.621002
# 2019-05-13  187.710  185.72      201.968628       200.907028
# 2019-05-14  186.410  188.66      195.447769       194.099976

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = pd.concat([df_merge,pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))],axis=0)
df_merge['2020-05-20':'2020-05-27']
# Out:
#               open   close  open_predicted  close_predicted
# 2020-05-20  316.68  319.23      315.948669       311.599640
# 2020-05-21  318.66  316.85      320.027893       315.426422
# 2020-05-22  315.77  318.89      320.773712       315.622894
# 2020-05-22     NaN     NaN             NaN              NaN
# 2020-05-23     NaN     NaN             NaN              NaN
# 2020-05-24     NaN     NaN             NaN              NaN
# 2020-05-25     NaN     NaN             NaN              NaN
# 2020-05-26     NaN     NaN             NaN              NaN
# 2020-05-27     NaN     NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2020-03-11':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2020-03-11':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2020-03-11':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2020-03-11':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# # THANK YOU!
